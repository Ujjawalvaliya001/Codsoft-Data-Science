# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline 

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Check Python Library Version

# %%
# Check Python Library Version
import pandas as pd 
import numpy as np 
import seaborn as sns 

print('numpy:{}'.format(np.__version__))
print('pandas:{}'.format(pd.__version__))
print('seaborn:{}'.format(sns.__version__))
# Out:
# numpy:1.26.4
# pandas:2.2.1
# seaborn:0.12.2

# %% [markdown]
# # Read CSV File

# %%
import numpy as np
import seaborn as sns
import pandas as pd 
import matplotlib.pyplot as plt
df = pd.read_csv("Titanic-Dataset.csv")
df.head().style.set_properties(**{'background-color': 'Yellow',
                           'color': 'Black',
                           'border-color': 'darkblack'})
# Out:
# <style type="text/css">
# #T_e9bbe_row0_col0, #T_e9bbe_row0_col1, #T_e9bbe_row0_col2, #T_e9bbe_row0_col3, #T_e9bbe_row0_col4, #T_e9bbe_row0_col5, #T_e9bbe_row0_col6, #T_e9bbe_row0_col7, #T_e9bbe_row0_col8, #T_e9bbe_row0_col9, #T_e9bbe_row0_col10, #T_e9bbe_row0_col11, #T_e9bbe_row1_col0, #T_e9bbe_row1_col1, #T_e9bbe_row1_col2, #T_e9bbe_row1_col3, #T_e9bbe_row1_col4, #T_e9bbe_row1_col5, #T_e9bbe_row1_col6, #T_e9bbe_row1_col7, #T_e9bbe_row1_col8, #T_e9bbe_row1_col9, #T_e9bbe_row1_col10, #T_e9bbe_row1_col11, #T_e9bbe_row2_col0, #T_e9bbe_row2_col1, #T_e9bbe_row2_col2, #T_e9bbe_row2_col3, #T_e9bbe_row2_col4, #T_e9bbe_row2_col5, #T_e9bbe_row2_col6, #T_e9bbe_row2_col7, #T_e9bbe_row2_col8, #T_e9bbe_row2_col9, #T_e9bbe_row2_col10, #T_e9bbe_row2_col11, #T_e9bbe_row3_col0, #T_e9bbe_row3_col1, #T_e9bbe_row3_col2, #T_e9bbe_row3_col3, #T_e9bbe_row3_col4, #T_e9bbe_row3_col5, #T_e9bbe_row3_col6, #T_e9bbe_row3_col7, #T_e9bbe_row3_col8, #T_e9bbe_row3_col9, #T_e9bbe_row3_col10, #T_e9bbe_row3_col11, #T_e9bbe_row4_col0, #T_e9bbe_row4_col1, #T_e9bbe_row4_col2, #T_e9bbe_row4_col3, #T_e9bbe_row4_col4, #T_e9bbe_row4_col5, #T_e9bbe_row4_col6, #T_e9bbe_row4_col7, #T_e9bbe_row4_col8, #T_e9bbe_row4_col9, #T_e9bbe_row4_col10, #T_e9bbe_row4_col11 {
#   background-color: Yellow;
#   color: Black;
#   border-color: darkblack;
# }
# </style>
# <table id="T_e9bbe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9bbe_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_e9bbe_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_e9bbe_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_e9bbe_level0_col3" class="col_heading level0 col3" >Name</th>
#       <th id="T_e9bbe_level0_col4" class="col_heading level0 col4" >Sex</th>
#       <th id="T_e9bbe_level0_col5" class="col_heading level0 col5" >Age</th>
#       <th id="T_e9bbe_level0_col6" class="col_heading level0 col6" >SibSp</th>
#       <th id="T_e9bbe_level0_col7" class="col_heading level0 col7" >Parch</th>
#       <th id="T_e9bbe_level0_col8" class="col_heading level0 col8" >Ticket</th>
#       <th id="T_e9bbe_level0_col9" class="col_heading level0 col9" >Fare</th>
#       <th id="T_e9bbe_level0_col10" class="col_heading level0 col10" >Cabin</th>
#       <th id="T_e9bbe_level0_col11" class="col_heading level0 col11" >Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9bbe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e9bbe_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_e9bbe_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_e9bbe_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_e9bbe_row0_col3" class="data row0 col3" >Braund, Mr. Owen Harris</td>
#       <td id="T_e9bbe_row0_col4" class="data row0 col4" >male</td>
#       <td id="T_e9bbe_row0_col5" class="data row0 col5" >22.000000</td>
#       <td id="T_e9bbe_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_e9bbe_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_e9bbe_row0_col8" class="data row0 col8" >A/5 21171</td>
#       <td id="T_e9bbe_row0_col9" class="data row0 col9" >7.250000</td>
#       <td id="T_e9bbe_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_e9bbe_row0_col11" class="data row0 col11" >S</td>
#     </tr>
#     <tr>
#       <th id="T_e9bbe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e9bbe_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_e9bbe_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_e9bbe_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_e9bbe_row1_col3" class="data row1 col3" >Cumings, Mrs. John Bradley (Florence Briggs Thayer)</td>
#       <td id="T_e9bbe_row1_col4" class="data row1 col4" >female</td>
#       <td id="T_e9bbe_row1_col5" class="data row1 col5" >38.000000</td>
#       <td id="T_e9bbe_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_e9bbe_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_e9bbe_row1_col8" class="data row1 col8" >PC 17599</td>
#       <td id="T_e9bbe_row1_col9" class="data row1 col9" >71.283300</td>
#       <td id="T_e9bbe_row1_col10" class="data row1 col10" >C85</td>
#       <td id="T_e9bbe_row1_col11" class="data row1 col11" >C</td>
#     </tr>
#     <tr>
#       <th id="T_e9bbe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e9bbe_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_e9bbe_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_e9bbe_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_e9bbe_row2_col3" class="data row2 col3" >Heikkinen, Miss. Laina</td>
#       <td id="T_e9bbe_row2_col4" class="data row2 col4" >female</td>
#       <td id="T_e9bbe_row2_col5" class="data row2 col5" >26.000000</td>
#       <td id="T_e9bbe_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_e9bbe_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_e9bbe_row2_col8" class="data row2 col8" >STON/O2. 3101282</td>
#       <td id="T_e9bbe_row2_col9" class="data row2 col9" >7.925000</td>
#       <td id="T_e9bbe_row2_col10" class="data row2 col10" >nan</td>
#       <td id="T_e9bbe_row2_col11" class="data row2 col11" >S</td>
#     </tr>
#     <tr>
#       <th id="T_e9bbe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e9bbe_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_e9bbe_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_e9bbe_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_e9bbe_row3_col3" class="data row3 col3" >Futrelle, Mrs. Jacques Heath (Lily May Peel)</td>
#       <td id="T_e9bbe_row3_col4" class="data row3 col4" >female</td>
#       <td id="T_e9bbe_row3_col5" class="data row3 col5" >35.000000</td>
#       <td id="T_e9bbe_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_e9bbe_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_e9bbe_row3_col8" class="data row3 col8" >113803</td>
#       <td id="T_e9bbe_row3_col9" class="data row3 col9" >53.100000</td>
#       <td id="T_e9bbe_row3_col10" class="data row3 col10" >C123</td>
#       <td id="T_e9bbe_row3_col11" class="data row3 col11" >S</td>
#     </tr>
#     <tr>
#       <th id="T_e9bbe_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e9bbe_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_e9bbe_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_e9bbe_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_e9bbe_row4_col3" class="data row4 col3" >Allen, Mr. William Henry</td>
#       <td id="T_e9bbe_row4_col4" class="data row4 col4" >male</td>
#       <td id="T_e9bbe_row4_col5" class="data row4 col5" >35.000000</td>
#       <td id="T_e9bbe_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_e9bbe_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_e9bbe_row4_col8" class="data row4 col8" >373450</td>
#       <td id="T_e9bbe_row4_col9" class="data row4 col9" >8.050000</td>
#       <td id="T_e9bbe_row4_col10" class="data row4 col10" >nan</td>
#       <td id="T_e9bbe_row4_col11" class="data row4 col11" >S</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Drop Columns from the dataframe

# %%
# Drop Columns from the dataframe
df_drop_Col = df.drop(['PassengerId','Name','Ticket'],axis=1)
df_drop_Col.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %% [markdown]
# # Drop Rows from the dataframe

# %%
df_drop_rows = df.drop(labels=[0,1,3,6],axis=0)
df_drop_rows.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 4            5         0       3
# 5            6         0       3
# 7            8         0       3
# 8            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S

# %% [markdown]
# # Describe function

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df[df['Survived']==0].describe().T.style.background_gradient \
(subset=['mean','std','50%','count'], cmap='RdPu')
# Out:
# <style type="text/css">
# #T_416d4_row0_col0, #T_416d4_row0_col1, #T_416d4_row0_col2, #T_416d4_row0_col5, #T_416d4_row1_col0, #T_416d4_row2_col0, #T_416d4_row4_col0, #T_416d4_row5_col0, #T_416d4_row6_col0 {
#   background-color: #49006a;
#   color: #f1f1f1;
# }
# #T_416d4_row1_col1, #T_416d4_row1_col2, #T_416d4_row1_col5, #T_416d4_row2_col2, #T_416d4_row3_col0, #T_416d4_row4_col1, #T_416d4_row4_col5, #T_416d4_row5_col1, #T_416d4_row5_col2, #T_416d4_row5_col5 {
#   background-color: #fff7f3;
#   color: #000000;
# }
# #T_416d4_row2_col1, #T_416d4_row2_col5, #T_416d4_row4_col2 {
#   background-color: #fff6f2;
#   color: #000000;
# }
# #T_416d4_row3_col1 {
#   background-color: #feebe7;
#   color: #000000;
# }
# #T_416d4_row3_col2 {
#   background-color: #feeeea;
#   color: #000000;
# }
# #T_416d4_row3_col5 {
#   background-color: #feece9;
#   color: #000000;
# }
# #T_416d4_row6_col1 {
#   background-color: #feeeeb;
#   color: #000000;
# }
# #T_416d4_row6_col2 {
#   background-color: #fde1de;
#   color: #000000;
# }
# #T_416d4_row6_col5 {
#   background-color: #fff3f0;
#   color: #000000;
# }
# </style>
# <table id="T_416d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_416d4_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_416d4_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_416d4_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_416d4_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_416d4_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_416d4_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_416d4_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_416d4_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_416d4_level0_row0" class="row_heading level0 row0" >PassengerId</th>
#       <td id="T_416d4_row0_col0" class="data row0 col0" >549.000000</td>
#       <td id="T_416d4_row0_col1" class="data row0 col1" >447.016393</td>
#       <td id="T_416d4_row0_col2" class="data row0 col2" >260.640469</td>
#       <td id="T_416d4_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_416d4_row0_col4" class="data row0 col4" >211.000000</td>
#       <td id="T_416d4_row0_col5" class="data row0 col5" >455.000000</td>
#       <td id="T_416d4_row0_col6" class="data row0 col6" >675.000000</td>
#       <td id="T_416d4_row0_col7" class="data row0 col7" >891.000000</td>
#     </tr>
#     <tr>
#       <th id="T_416d4_level0_row1" class="row_heading level0 row1" >Survived</th>
#       <td id="T_416d4_row1_col0" class="data row1 col0" >549.000000</td>
#       <td id="T_416d4_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_416d4_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_416d4_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_416d4_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_416d4_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_416d4_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_416d4_row1_col7" class="data row1 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_416d4_level0_row2" class="row_heading level0 row2" >Pclass</th>
#       <td id="T_416d4_row2_col0" class="data row2 col0" >549.000000</td>
#       <td id="T_416d4_row2_col1" class="data row2 col1" >2.531876</td>
#       <td id="T_416d4_row2_col2" class="data row2 col2" >0.735805</td>
#       <td id="T_416d4_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_416d4_row2_col4" class="data row2 col4" >2.000000</td>
#       <td id="T_416d4_row2_col5" class="data row2 col5" >3.000000</td>
#       <td id="T_416d4_row2_col6" class="data row2 col6" >3.000000</td>
#       <td id="T_416d4_row2_col7" class="data row2 col7" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_416d4_level0_row3" class="row_heading level0 row3" >Age</th>
#       <td id="T_416d4_row3_col0" class="data row3 col0" >424.000000</td>
#       <td id="T_416d4_row3_col1" class="data row3 col1" >30.626179</td>
#       <td id="T_416d4_row3_col2" class="data row3 col2" >14.172110</td>
#       <td id="T_416d4_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_416d4_row3_col4" class="data row3 col4" >21.000000</td>
#       <td id="T_416d4_row3_col5" class="data row3 col5" >28.000000</td>
#       <td id="T_416d4_row3_col6" class="data row3 col6" >39.000000</td>
#       <td id="T_416d4_row3_col7" class="data row3 col7" >74.000000</td>
#     </tr>
#     <tr>
#       <th id="T_416d4_level0_row4" class="row_heading level0 row4" >SibSp</th>
#       <td id="T_416d4_row4_col0" class="data row4 col0" >549.000000</td>
#       <td id="T_416d4_row4_col1" class="data row4 col1" >0.553734</td>
#       <td id="T_416d4_row4_col2" class="data row4 col2" >1.288399</td>
#       <td id="T_416d4_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_416d4_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_416d4_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_416d4_row4_col6" class="data row4 col6" >1.000000</td>
#       <td id="T_416d4_row4_col7" class="data row4 col7" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_416d4_level0_row5" class="row_heading level0 row5" >Parch</th>
#       <td id="T_416d4_row5_col0" class="data row5 col0" >549.000000</td>
#       <td id="T_416d4_row5_col1" class="data row5 col1" >0.329690</td>
#       <td id="T_416d4_row5_col2" class="data row5 col2" >0.823166</td>
#       <td id="T_416d4_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_416d4_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_416d4_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_416d4_row5_col6" class="data row5 col6" >0.000000</td>
#       <td id="T_416d4_row5_col7" class="data row5 col7" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_416d4_level0_row6" class="row_heading level0 row6" >Fare</th>
#       <td id="T_416d4_row6_col0" class="data row6 col0" >549.000000</td>
#       <td id="T_416d4_row6_col1" class="data row6 col1" >22.117887</td>
#       <td id="T_416d4_row6_col2" class="data row6 col2" >31.388207</td>
#       <td id="T_416d4_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_416d4_row6_col4" class="data row6 col4" >7.854200</td>
#       <td id="T_416d4_row6_col5" class="data row6 col5" >10.500000</td>
#       <td id="T_416d4_row6_col6" class="data row6 col6" >26.000000</td>
#       <td id="T_416d4_row6_col7" class="data row6 col7" >263.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.describe(percentiles=[0.05,0.25,0.35,0.5,0.75,0.85,0.95,0.995,0.999])
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 5%       45.500000    0.000000    1.000000    4.000000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 35%     312.500000    0.000000    2.000000   24.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# 85%     757.500000    1.000000    3.000000   45.000000    1.000000
# 95%     846.500000    1.000000    3.000000   56.000000    3.000000
# 99.5%   886.550000    1.000000    3.000000   70.717500    8.000000
# 99.9%   890.110000    1.000000    3.000000   75.722000    8.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 5%       0.000000    7.225000
# 25%      0.000000    7.910400
# 35%      0.000000    9.000000
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# 85%      1.000000   56.495800
# 95%      2.000000  112.079150
# 99.5%    5.000000  263.000000
# 99.9%    5.110000  512.329200
# max      6.000000  512.329200

# %% [markdown]
# # Correlation function

# %%
df[['Survived', 'Pclass', 'Age', 'SibSp','Parch', 'Fare']].corr()
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# Pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# Age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# SibSp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# Parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# Fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
corr = df.groupby(["Embarked"])[["Fare" , "Age"]].corr()
corr.head()

sns.heatmap(corr , annot=True , fmt =".2f")
plt.xlabel("Vars")
plt.ylabel("age category")
plt.title("corr between age and Fare according to Embarked (catgorey)")
plt.show()

# %%
X = df[['Pclass', 'Age', 'SibSp','Parch', 'Fare']]
y = df['Survived']
X.corrwith(y).plot.bar(
        figsize = (16, 4), title = "Correlation with Titanic", fontsize = 15,
        rot = 90, grid = True)
plt.show()

# %%
corr = df[['Pclass', 'Age', 'SibSp','Parch', 'Fare']].corr()
plt.figure(dpi=100)
plt.title('Correlation Analysis')
sns.heatmap(corr,annot=True,lw=0,linecolor='white',cmap='viridis',fmt = "0.2f")
plt.xticks(rotation=90)
plt.yticks(rotation = 0)
plt.show()

# %%
corr = df[['Pclass', 'Age', 'SibSp','Parch', 'Fare']].corr()
mask = np.triu(np.ones_like(corr,dtype = bool))
plt.figure(dpi=100)
plt.title('Correlation Analysis')
sns.heatmap(corr,mask=mask,annot=True,lw=0,linecolor='white',cmap='viridis',fmt = "0.2f")
plt.xticks(rotation=90)
plt.yticks(rotation = 0)
plt.show()
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
df[['Age','Fare','Pclass']].agg(['sum','max','mean','std','skew','kurt'])
# Out:
#                Age          Fare       Pclass
# sum   21205.170000  28693.949300  2057.000000
# max      80.000000    512.329200     3.000000
# mean     29.699118     32.204208     2.308642
# std      14.526497     49.693429     0.836071
# skew      0.389108      4.787317    -0.630548
# kurt      0.178274     33.398141    -1.280015

# %%
df.groupby("Embarked").agg({"Fare": np.mean, "Sex": np.size})
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7796\3283244327.py:1: FutureWarning: The provided callable <function mean at 0x00000216FAD38400> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby("Embarked").agg({"Fare": np.mean, "Sex": np.size})
#                Fare  Sex
# Embarked
# C         59.954144  168
# Q         13.276030   77
# S         27.079812  644

# %%
df.groupby(["Embarked", "Pclass"]).agg({"Fare": [np.size, np.mean]})
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7796\1918294047.py:1: FutureWarning: The provided callable <function mean at 0x00000216FAD38400> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby(["Embarked", "Pclass"]).agg({"Fare": [np.size, np.mean]})
#                 Fare
#                 size        mean
# Embarked Pclass
# C        1        85  104.718529
#          2        17   25.358335
#          3        66   11.214083
# Q        1         2   90.000000
#          2         3   12.350000
#          3        72   11.183393
# S        1       127   70.364862
#          2       164   20.327439
#          3       353   14.644083

# %%
df.pivot_table(index='Pclass',values='Age', aggfunc=np.median)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7796\896296842.py:1: FutureWarning: The provided callable <function median at 0x00000216FAE70040> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df.pivot_table(index='Pclass',values='Age', aggfunc=np.median)
#          Age
# Pclass
# 1       37.0
# 2       29.0
# 3       24.0

# %%
x=pd.DataFrame(pd.pivot_table(df,index=['Sex','Embarked'],aggfunc='count')['Fare'])
x
# Out:
#                  Fare
# Sex    Embarked
# female C           73
#        Q           36
#        S          203
# male   C           95
#        Q           41
#        S          441

# %%
df.groupby(["Embarked", "Pclass"]).agg({"Fare": [np.size, np.mean]})
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7796\3801662884.py:1: FutureWarning: The provided callable <function mean at 0x00000216FAD38400> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby(["Embarked", "Pclass"]).agg({"Fare": [np.size, np.mean]})
#                 Fare
#                 size        mean
# Embarked Pclass
# C        1        85  104.718529
#          2        17   25.358335
#          3        66   11.214083
# Q        1         2   90.000000
#          2         3   12.350000
#          3        72   11.183393
# S        1       127   70.364862
#          2       164   20.327439
#          3       353   14.644083

# %%
df.groupby("Embarked").agg({"Fare": np.mean, "Sex": np.size})
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7796\3283244327.py:1: FutureWarning: The provided callable <function mean at 0x00000216FAD38400> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby("Embarked").agg({"Fare": np.mean, "Sex": np.size})
#                Fare  Sex
# Embarked
# C         59.954144  168
# Q         13.276030   77
# S         27.079812  644

# %%
df.groupby('Embarked').Fare.agg(['count', 'mean', 'sum']).sort_values('sum').tail()
# Out:
#           count       mean         sum
# Embarked
# Q            77  13.276030   1022.2543
# C           168  59.954144  10072.2962
# S           644  27.079812  17439.3988

# %% [markdown]
# # value_counts function

# %%
df['Embarked'].value_counts().to_frame()
# Out:
#           count
# Embarked
# S           644
# C           168
# Q            77

# %%
df['Embarked'].value_counts().tolist()
# Out:
# [644, 168, 77]

# %%
males = df[df['Sex'] == 'male']
males['Survived'].value_counts()/len(males)
# Out:
# Survived
# 0    0.811092
# 1    0.188908
# Name: count, dtype: float64

# %%
df['Embarked'][df['Sex']=='female'].value_counts(normalize=True)*100
# Out:
# Embarked
# S    65.064103
# C    23.397436
# Q    11.538462
# Name: proportion, dtype: float64
